# %%
import pandas as pd

# %%
import numpy as np

# %%
df = pd.read_csv("annual-enterprise-survey-2021-financial-year-provisional-csv.csv")

# %%
display(df)
# Out:
#        Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0      2021                     Level 1                99999
# 1      2021                     Level 1                99999
# 2      2021                     Level 1                99999
# 3      2021                     Level 1                99999
# 4      2021                     Level 1                99999
# ...     ...                         ...                  ...
# 41710  2013                     Level 3                 ZZ11
# 41711  2013                     Level 3                 ZZ11
# 41712  2013                     Level 3                 ZZ11
# 41713  2013                     Level 3                 ZZ11
# 41714  2013                     Level 3                 ZZ11
#
#              Industry_name_NZSIOC               Units Variable_code  \
# 0                  All industries  Dollars (millions)           H01
# 1                  All industries  Dollars (millions)           H04
# ...

# %%
df.drop([2,3],axis=0,inplace=True)
df.head()
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 1  2021                     Level 1                99999       All industries
# 4  2021                     Level 1                99999       All industries
# 5  2021                     Level 1                99999       All industries
# 6  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 4  Dollars (millions)           H08
# 5  Dollars (millions)           H09
# 6  Dollars (millions)           H10
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# 1  Sales, government funding, grants and subsidies  Financial performance
# ...

# %%
df.drop('Value',axis=1,inplace=True)
df.head(6)
# Out:
#    Year Industry_aggregation_NZSIOC Industry_code_NZSIOC Industry_name_NZSIOC  \
# 0  2021                     Level 1                99999       All industries
# 1  2021                     Level 1                99999       All industries
# 4  2021                     Level 1                99999       All industries
# 5  2021                     Level 1                99999       All industries
# 6  2021                     Level 1                99999       All industries
# 7  2021                     Level 1                99999       All industries
#
#                 Units Variable_code  \
# 0  Dollars (millions)           H01
# 1  Dollars (millions)           H04
# 4  Dollars (millions)           H08
# 5  Dollars (millions)           H09
# 6  Dollars (millions)           H10
# 7  Dollars (millions)           H11
#
#                                      Variable_name      Variable_category  \
# 0                                     Total income  Financial performance
# ...

# %%
df['Year'].astype('int')
# Out:
# 0        2021
# 1        2021
# 4        2021
# 5        2021
# 6        2021
#          ...
# 41710    2013
# 41711    2013
# 41712    2013
# 41713    2013
# 41714    2013
# Name: Year, Length: 41713, dtype: int32

# %%
df['Variable_category'].astype('string')
# Out:
# 0        Financial performance
# 1        Financial performance
# 4        Financial performance
# 5        Financial performance
# 6        Financial performance
#                  ...
# 41710         Financial ratios
# 41711         Financial ratios
# 41712         Financial ratios
# 41713         Financial ratios
# 41714         Financial ratios
# Name: Variable_category, Length: 41713, dtype: string

# %%
df['Industry_aggregation_NZSIOC'].astype('string')
# Out:
# 0        Level 1
# 1        Level 1
# 4        Level 1
# 5        Level 1
# 6        Level 1
#           ...
# 41710    Level 3
# 41711    Level 3
# 41712    Level 3
# 41713    Level 3
# 41714    Level 3
# Name: Industry_aggregation_NZSIOC, Length: 41713, dtype: string

# %%
df['Industry_name_NZSIOC'].astype('string')
# Out:
# 0                    All industries
# 1                    All industries
# 4                    All industries
# 5                    All industries
# 6                    All industries
#                     ...
# 41710    Food product manufacturing
# 41711    Food product manufacturing
# 41712    Food product manufacturing
# 41713    Food product manufacturing
# 41714    Food product manufacturing
# Name: Industry_name_NZSIOC, Length: 41713, dtype: string

# %%
df['Variable_name'].astype('string')
# Out:
# 0                                           Total income
# 1        Sales, government funding, grants and subsidies
# 4                                      Total expenditure
# 5                                 Interest and donations
# 6                                         Indirect taxes
#                               ...
# 41710                                        Quick ratio
# 41711                Margin on sales of goods for resale
# 41712                                   Return on equity
# 41713                             Return on total assets
# 41714                              Liabilities structure
# Name: Variable_name, Length: 41713, dtype: string

# %%
df['Industry_code_ANZSIC06'].astype('string')
# Out:
# 0        ANZSIC06 divisions A-S (excluding classes K633...
# 1        ANZSIC06 divisions A-S (excluding classes K633...
# 4        ANZSIC06 divisions A-S (excluding classes K633...
# 5        ANZSIC06 divisions A-S (excluding classes K633...
# 6        ANZSIC06 divisions A-S (excluding classes K633...
#                                ...
# 41710    ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41711    ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41712    ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41713    ANZSIC06 groups C111, C112, C113, C114, C115, ...
# 41714    ANZSIC06 groups C111, C112, C113, C114, C115, ...
# Name: Industry_code_ANZSIC06, Length: 41713, dtype: string

# %%
df['Variable_code'].astype('string')
# Out:
# 0        H01
# 1        H04
# 4        H08
# 5        H09
# 6        H10
#         ...
# 41710    H37
# 41711    H38
# 41712    H39
# 41713    H40
# 41714    H41
# Name: Variable_code, Length: 41713, dtype: string

# %%
df.replace("?", np.nan, inplace = True)
df.head(10)
# Out:
#     Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0   2021                     Level 1                99999
# 1   2021                     Level 1                99999
# 4   2021                     Level 1                99999
# 5   2021                     Level 1                99999
# 6   2021                     Level 1                99999
# 7   2021                     Level 1                99999
# 8   2021                     Level 1                99999
# 9   2021                     Level 1                99999
# 10  2021                     Level 1                99999
# 11  2021                     Level 1                99999
#
#    Industry_name_NZSIOC               Units Variable_code  \
# 0        All industries  Dollars (millions)           H01
# 1        All industries  Dollars (millions)           H04
# 4        All industries  Dollars (millions)           H08
# 5        All industries  Dollars (millions)           H09
# ...

# %%
missing_data = df.isnull()
missing_data.head()
# Out:
#     Year  Industry_aggregation_NZSIOC  Industry_code_NZSIOC  \
# 0  False                        False                 False
# 1  False                        False                 False
# 4  False                        False                 False
# 5  False                        False                 False
# 6  False                        False                 False
#
#    Industry_name_NZSIOC  Units  Variable_code  Variable_name  \
# 0                 False  False          False          False
# 1                 False  False          False          False
# 4                 False  False          False          False
# 5                 False  False          False          False
# 6                 False  False          False          False
#
#    Variable_category  Industry_code_ANZSIC06
# 0              False                   False
# 1              False                   False
# 4              False                   False
# 5              False                   False
# ...

# %%
for column in missing_data.columns.values.tolist():
    print("Column Name:" + column)
    print (missing_data[column].value_counts())
# Out:
# Column Name:Year
# False    41713
# Name: Year, dtype: int64
# Column Name:Industry_aggregation_NZSIOC
# False    41713
# Name: Industry_aggregation_NZSIOC, dtype: int64
# Column Name:Industry_code_NZSIOC
# False    41713
# Name: Industry_code_NZSIOC, dtype: int64
# Column Name:Industry_name_NZSIOC
# False    41713
# Name: Industry_name_NZSIOC, dtype: int64
# Column Name:Units
# False    41713
# Name: Units, dtype: int64
# Column Name:Variable_code
# False    41713
# Name: Variable_code, dtype: int64
# Column Name:Variable_name
# False    41713
# Name: Variable_name, dtype: int64
# Column Name:Variable_category
# False    41713
# Name: Variable_category, dtype: int64
# Column Name:Industry_code_ANZSIC06
# False    41713
# Name: Industry_code_ANZSIC06, dtype: int64

# %%
bins = np.linspace(min(df["Year"]), max(df["Year"]), 4)
group_names = ['Old', 'Medium', 'Modern']
df['year-binned'] = pd.cut(df['Year'], bins, labels=group_names, include_lowest=True )
df[['Year','year-binned']].head(20)
# Out:
#       Year year-binned
# 0   2021.0      Modern
# 1   2021.0      Modern
# 2   2021.0      Modern
# 3   2021.0      Modern
# 4   2021.0      Modern
# 5   2021.0      Modern
# 6   2021.0      Modern
# 7   2021.0      Modern
# 8   2021.0      Modern
# 9   2021.0      Modern
# 10  2021.0      Modern
# 11  2021.0      Modern
# 12  2021.0      Modern
# 13  2021.0      Modern
# 14  2021.0      Modern
# 15  2021.0      Modern
# 16  2021.0      Modern
# 17  2021.0      Modern
# 18  2021.0      Modern
# 19  2021.0      Modern

# %%
# %matplotlib inline
import matplotlib as plt
from matplotlib import pyplot
pyplot.bar(group_names, df["year-binned"].count())
# Out:
# <BarContainer object of 3 artists>
