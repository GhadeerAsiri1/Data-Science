# %%
#importing a csv into python
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("creditcard[1].csv")

# %%
display(df)
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 0            0.0  -1.359807  -0.072781  2.536347  1.378155 -0.338321
# 1            0.0   1.191857   0.266151  0.166480  0.448154  0.060018
# 2            1.0  -1.358354  -1.340163  1.773209  0.379780 -0.503198
# 3            1.0  -0.966272  -0.185226  1.792993 -0.863291 -0.010309
# 4            2.0  -1.158233   0.877737  1.548718  0.403034 -0.407193
# ...          ...        ...        ...       ...       ...       ...
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# ...

# %%
#number of rows and columns
df.shape
# Out:
# (284807, 31)

# %%
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
df.tail()
# Out:
#             Time         V1         V2        V3        V4        V5  \
# 284802  172786.0 -11.881118  10.071785 -9.834783 -2.066656 -5.364473
# 284803  172787.0  -0.732789  -0.055080  2.035030 -0.738589  0.868229
# 284804  172788.0   1.919565  -0.301254 -3.249640 -0.557828  2.630515
# 284805  172788.0  -0.240440   0.530483  0.702510  0.689799 -0.377961
# 284806  172792.0  -0.533413  -0.189733  0.703337 -0.506271 -0.012546
#
#               V6        V7        V8        V9  ...       V21       V22  \
# 284802 -2.606837 -4.918215  7.305334  1.914428  ...  0.213454  0.111864
# 284803  1.058415  0.024330  0.294869  0.584800  ...  0.214205  0.924384
# 284804  3.031260 -0.296827  0.708417  0.432454  ...  0.232045  0.578229
# 284805  0.623708 -0.686180  0.679145  0.392087  ...  0.265245  0.800049
# 284806 -0.649617  1.577006 -0.414650  0.486180  ...  0.261057  0.643078
#
#              V23       V24       V25       V26       V27       V28  Amount  \
# ...

# %%
#check data types
df.dtypes
# Out:
# Time      float64
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
df.drop([4],axis=0,inplace=True)
df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 5   2.0 -0.425966  0.960523  1.141109 -0.168252  0.420987 -0.029728  0.476201
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 5  0.260314 -0.568671  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
#
# ...

# %%
df.drop('V2',axis=1,inplace=True)
df.head()
# Out:
#    Time        V1        V3        V4        V5        V6        V7        V8  \
# 0   0.0 -1.359807  2.536347  1.378155 -0.338321  0.462388  0.239599  0.098698
# 1   0.0  1.191857  0.166480  0.448154  0.060018 -0.082361 -0.078803  0.085102
# 2   1.0 -1.358354  1.773209  0.379780 -0.503198  1.800499  0.791461  0.247676
# 3   1.0 -0.966272  1.792993 -0.863291 -0.010309  1.247203  0.237609  0.377436
# 5   2.0 -0.425966  1.141109 -0.168252  0.420987 -0.029728  0.476201  0.260314
#
#          V9       V10  ...       V21       V22       V23       V24       V25  \
# 0  0.363787  0.090794  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2 -1.514654  0.207643  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 5 -0.568671 -0.371407  ... -0.208254 -0.559825 -0.026398 -0.371427 -0.232794
#
# ...

# %%
messing_data = df.isnull()
messing_data.head()
# Out:
#     Time     V1     V3     V4     V5     V6     V7     V8     V9    V10  ...  \
# 0  False  False  False  False  False  False  False  False  False  False  ...
# 1  False  False  False  False  False  False  False  False  False  False  ...
# 2  False  False  False  False  False  False  False  False  False  False  ...
# 3  False  False  False  False  False  False  False  False  False  False  ...
# 5  False  False  False  False  False  False  False  False  False  False  ...
#
#      V21    V22    V23    V24    V25    V26    V27    V28  Amount  Class
# 0  False  False  False  False  False  False  False  False   False  False
# 1  False  False  False  False  False  False  False  False   False  False
# 2  False  False  False  False  False  False  False  False   False  False
# 3  False  False  False  False  False  False  False  False   False  False
# 5  False  False  False  False  False  False  False  False   False  False
#
# [5 rows x 30 columns]

# %%
df.rename(columns={'Class':'Result'}, inplace=True)
df.columns
# Out:
# Index(['Time', 'V1', 'V3', 'V4', 'V5', 'V6', 'V7', 'V8', 'V9', 'V10', 'V11',
#        'V12', 'V13', 'V14', 'V15', 'V16', 'V17', 'V18', 'V19', 'V20', 'V21',
#        'V22', 'V23', 'V24', 'V25', 'V26', 'V27', 'V28', 'Amount', 'Result'],
#       dtype='object')

# %%
df['average']=df.sum(axis=1)

# %%
df.isnull().sum()
# Out:
# Time       0
# V1         0
# V3         0
# V4         0
# V5         0
# V6         0
# V7         0
# V8         0
# V9         0
# V10        0
# V11        0
# V12        0
# V13        0
# V14        0
# V15        0
# V16        0
# V17        0
# V18        0
# V19        0
# V20        0
# V21        0
# V22        0
# V23        0
# V24        0
# V25        0
# V26        0
# V27        0
# V28        0
# Amount     0
# Result     0
# average    0
# dtype: int64

# %%
df.describe()
# Out:
#                 Time             V1             V3             V4  \
# count  284806.000000  284806.000000  284806.000000  284806.000000
# mean    94814.192475       0.000004      -0.000005      -0.000001
# std     47487.896998       1.958698       1.516255       1.415871
# min         0.000000     -56.407510     -48.325589      -5.683171
# 25%     54202.250000      -0.920370      -0.890368      -0.848642
# 50%     84692.500000       0.018109       0.179846      -0.019848
# 75%    139320.750000       1.315645       1.027185       0.743348
# max    172792.000000       2.454930       9.382558      16.875344
#
#                   V5            V6             V7            V8  \
# count  284806.000000  2.848060e+05  284806.000000  2.848060e+05
# mean        0.000001 -3.367958e-07      -0.000002  9.498841e-07
# std         1.380249  1.332273e+00       1.237095  1.194355e+00
# min      -113.743307 -2.616051e+01     -43.557242 -7.321672e+01
# ...

# %%
df.Amount   #Select column to filter
# Out:
# 0         149.62
# 1           2.69
# 2         378.66
# 3         123.50
# 5           3.67
#            ...
# 284802      0.77
# 284803     24.79
# 284804     67.88
# 284805     10.00
# 284806    217.00
# Name: Amount, Length: 284806, dtype: float64

# %%
 df.set_index('V1', inplace=True)

# %%
df.head(4)
# Out:
#    Time        V1        V3        V4        V5        V6        V7        V8  \
# 0   0.0 -1.359807  2.536347  1.378155 -0.338321  0.462388  0.239599  0.098698
# 1   0.0  1.191857  0.166480  0.448154  0.060018 -0.082361 -0.078803  0.085102
# 2   1.0 -1.358354  1.773209  0.379780 -0.503198  1.800499  0.791461  0.247676
# 3   1.0 -0.966272  1.792993 -0.863291 -0.010309  1.247203  0.237609  0.377436
#
#          V9       V10  ...       V22       V23       V24       V25       V26  \
# 0  0.363787  0.090794  ...  0.277838 -0.110474  0.066928  0.128539 -0.189115
# 1 -0.255425 -0.166974  ... -0.638672  0.101288 -0.339846  0.167170  0.125895
# 2 -1.514654  0.207643  ...  0.771679  0.909412 -0.689281 -0.327642 -0.139097
# 3 -1.387024 -0.054952  ...  0.005274 -0.190321 -1.175575  0.647376 -0.221929
#
#         V27       V28  Amount  Result     average
# 0  0.133558 -0.021053  149.62       0  310.641561
# 1 -0.008983  0.014724    2.69       0   13.955937
# ...

# %%
df['Result'].value_counts()   # Data is Not Balanced
# Out:
# 0    284314
# 1       492
# Name: Result, dtype: int64

# %%
df['Result'].value_counts().plot.bar()
# Out:
# <AxesSubplot:>

# %%
data = df['Result'].value_counts()
data.plot(kind='line')
plt.title(' Result of Detection ')
plt.show()

# %%
data = df['Result'].value_counts()
data.plot(kind='pie')
plt.title(' Result of Detection ')
plt.show()

# %%
df['V12'].value_counts().sort_index().plot.line()
# Out:
# <AxesSubplot:>

# %%
df['V3'].value_counts().sort_index().plot.line()
# Out:
# <AxesSubplot:>

# %%
df['Amount'].value_counts()
# Out:
# 1.00       13688
# 1.98        6044
# 0.89        4872
# 9.99        4747
# 15.00       3280
#            ...
# 62.09          1
# 552.05         1
# 1467.75        1
# 196.68         1
# 95.63          1
# Name: Amount, Length: 32767, dtype: int64

# %%
amount = df['Amount'].value_counts()
amount.sort_index().plot.line()
# Out:
# <AxesSubplot:>

# %%
df['Time'].value_counts()
# Out:
# 163152.0    36
# 64947.0     26
# 68780.0     25
# 3767.0      21
# 3770.0      20
#             ..
# 127750.0     1
# 62260.0      1
# 62259.0      1
# 127753.0     1
# 172792.0     1
# Name: Time, Length: 124592, dtype: int64

# %%
time = df['Time'].value_counts()
time.sort_index(inplace=True)
time
# Out:
# 0.0         2
# 1.0         2
# 2.0         1
# 4.0         1
# 7.0         2
#            ..
# 172785.0    1
# 172786.0    1
# 172787.0    1
# 172788.0    2
# 172792.0    1
# Name: Time, Length: 124592, dtype: int64

# %%
time.plot.line()
# Out:
# <AxesSubplot:>

# %%
indexes0 = df[ df['Result'] == 0].index[::800]
indexes1 = df[ df['Result'] == 1].index

all_indexes = indexes0.append(indexes1)

newDf = df.loc[all_indexes].Result.value_counts().plot.pie()

# %%
zeros = df[df['Result'] == 0].sample(492)
ones = df[df['Result'] == 1]
balancedDf = zeros.append(ones)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_2488\2023090841.py:3: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   balancedDf = zeros.append(ones)

# %%
balancedDf.Result.value_counts().plot()
# Out:
# <AxesSubplot:>
